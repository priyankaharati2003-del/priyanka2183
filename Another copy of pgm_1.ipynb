# %%
file=open("/content/hello.text","r")
content=file.read()
print(content)
# Out:
# Hello, world!

# %%
file=open("hello.text.txt","r")
for line in file:
    print(line)
file.close()
# Out:
# hi good morning

# %%
file=open("hello.txt.txt","r")
for line in file:
  print(line)
file.close()
# Out:
# good morning everyone
#
# i am learning python
#
# in gkvk

# %%
file=open("hello.txt.txt","w")
file.write("hello everyone!")
file.close()
print(file)
# Out:
# <_io.TextIOWrapper name='hello.txt.txt' mode='w' encoding='utf-8'>

# %%
file=open("hlo.txt.txt","w")
file.write("hello everyone")
file.close()
print(file)
# Out:
# <_io.TextIOWrapper name='hlo.txt.txt' mode='w' encoding='utf-8'>

# %%
file=open("/content/hello.text.txt","r")
content=file.read()
print(content)
# Out:
# hello everyone!

# %%
# Define the nutrients and their potential ranges or combinations
nutrients_data = {
    'N (Nitrogen) %': [10, 20, 15, 5, 25],
    'P (Phosphorus) %': [5, 10, 10, 15, 5],
    'K (Potassium) %': [10, 10, 15, 10, 20],
    'Dosage per Plant (grams)': [5, 10, 8, 7, 12],
    'Frequency (weeks)': [2, 4, 3, 2, 4],
    'Plant Type': ['Flowering', 'Foliage', 'Fruiting', 'Vegetable', 'All-purpose']

}

# Create a DataFrame
fertilizer_table = pd.DataFrame(nutrients_data)

# Display the table
display(fertilizer_table)
# Out:
#    N (Nitrogen) %  P (Phosphorus) %  K (Potassium) %  \
# 0              10                 5               10
# 1              20                10               10
# 2              15                10               15
# 3               5                15               10
# 4              25                 5               20
#
#    Dosage per Plant (grams)  Frequency (weeks)   Plant Type
# 0                         5                  2    Flowering
# 1                        10                  4      Foliage
# 2                         8                  3     Fruiting
# 3                         7                  2    Vegetable
# 4                        12                  4  All-purpose

# %%
file=open("/content/assign.txt.txt","r")
content=file.read()
print(content)
# Out:
#                     sl.no     N(nitrogen)%  P(phosphorous)%  K(potassium)%  Dosage per plant(grams)  Frequency(weeks) Plant type
#                       0           10             5                10                5                         2         flowering
#                       1           20            10                10              10                        4         foliage
#                       2           15            10               15              8                         3          fruiting
#                       3            5            15               10              7                        2         vegetables
#                       4           25             5               20              12                        4          all purpose

# %%
file=open("assign.txt.txt", "a")
file.write("\nLearning File Handling")
file.close()
